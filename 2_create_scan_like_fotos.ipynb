# %%
# import the necessary packages
from PIL import Image
import pytesseract
import cv2
import os
import matplotlib.pyplot as plt
    
# %matplotlib inline

# %%
image_path = 'rechnung.jpg'

image = cv2.imread(image_path)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# write the grayscale image to disk as a temporary file so we can
# apply OCR to it
filename = "{}.png".format(os.getpid())
cv2.imwrite(filename, gray)
# Out:
# True

# %%
# load the image as a PIL/Pillow image, apply OCR, 
text = pytesseract.image_to_string(Image.open(filename))

print(text)
# Out:
# A m me
# Mr str. u
# mm mm.
#
# M: um - 2» cm 31
# swank. Wm
#
# M: REENNUNE u av 29» “mus
#
#
#
# mum 7| Badumr‘ KeHmr ‘
# u m we mm. mm 5.50 am a
#
# u (350:) was Erdmss. :memssmn an a
# 1x mm) was aummm Mlmerﬂ.
#
# 5,00 am a
# Ix um) va. Baum I w m a
#
#
#
#
#
#
#
# 20,60 EUR
# ml. 3 m (Luv 3‘23 am
# Mm um an
#
# Intel: ‘ ‘ ’ . . 20,60 EUR
#
# Vvelen um «I. 1mm kwm‘
# Aui Mvuﬂersehzm an demacm mal wedev!
# 1m ASIA mm mu
#
# ﬁx

# %%
# show the output images

#for i in [image, gray]:
 #   plt.imshow(i)
plt.imshow(image)

# %%
# and then delete
# the temporary file
os.remove(filename)
